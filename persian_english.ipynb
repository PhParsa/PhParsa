# %% [markdown]
# <a href="https://colab.research.google.com/github/PhParsa/PhParsa/blob/main/persian_english.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install keras keras-hub --upgrade -q

# %%
import os
os.environ["KERAS_BACKEND"] = "jax"

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"This cell requires the {required} backend. To run it, change KERAS_BACKEND to "
            f"\"{required}\" at the top of the notebook, restart the runtime, and rerun the notebook."
        )

# %%
import keras
import pathlib
import tensorflow as tf
from keras import layers

# %%
zip_path = keras.utils.get_file(
    origin=(
        "https://datasets.s3.ir-tbz-sh1.arvanstorage.ir/nmt%2Fnmt.tar.xz"
    ),
    fname="far-eng",
    extract=True,
)
text_path = pathlib.Path(zip_path) / "far-eng" / "spa.txt"
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4387/2251369658.py in <cell line: 0>()
# ----> 1 zip_path = keras.utils.get_file(
#       2     origin=(
#       3         "https://datasets.s3.ir-tbz-sh1.arvanstorage.ir/nmt%2Fnmt.tar.xz"
#       4     ),
#       5     fname="far-eng",
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/file_utils.py in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir, force_download)
#     383         try:
#     384             try:
# --> 385                 urlretrieve(origin, download_target, DLProgbar())
#     386             except urllib.error.HTTPError as e:
#     387                 raise Exception(error_msg.format(origin, e.code, e.msg))
#
# /usr/lib/python3.12/urllib/request.py in urlretrieve(url, filename, reporthook, data)
# ...

# %%
import tarfile
import pathlib
import keras

zip_path = keras.utils.get_file(
    origin="https://datasets.s3.ir-tbz-sh1.arvanstorage.ir/nmt%2Fnmt.tar.xz",
    fname="nmt.tar.xz",
    extract=False,
)

with tarfile.open(zip_path, "r:xz") as tar:
    for member in tar.getmembers():
        print(member.name)
